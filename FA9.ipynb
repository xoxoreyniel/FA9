# %%
import pandas as pd
import matplotlib.pyplot as plt

# Create a dictionary to represent the descriptive statistics
data = {
    'Academic Rank': ['AssocProf', 'AsstProf', 'Prof'],
    'Median': [103613.0, 78500.0, 123321.5],
    'Mean': [91786.231, 81362.789, 123624.804],
    'Std. Deviation': [18571.184, 9381.245, 24850.288],
    'Coefficient of Variation': [0.202, 0.115, 0.201],
    'Skewness': [-0.151, 0.031, 0.070],
    'Kurtosis': [-1.614, -1.011, 0.201],
    'Minimum': [62884.0, 63100.0, 57800.0],
    'Maximum': [119800.0, 97032.0, 186960.0],
    '25th percentile': [74830.0, 74096.0, 105112.5],
    '50th percentile': [103613.0, 78500.0, 123321.5],
    '75th percentile': [104542.0, 91150.0, 143512.25],
    '10th percentile': [71512.0, 72500.0, 93675.0],
    '20th percentile': [73912.0, 73300.0, 103275.0],
    '30th percentile': [76432.0, 74832.8, 108473.0],
    '40th percentile': [80528.0, 77100.0, 116450.0],
    '60th percentile': [103798.8, 84045.0, 127512.0],
    '70th percentile': [104213.2, 89800.0, 135889.0],
    '80th percentile': [106021.6, 91580.0, 148750.0],
    '90th percentile': [109121.6, 92000.0, 154750.0]
}

# Create a DataFrame from the dictionary
df = pd.DataFrame(data)

# Print the DataFrame
print("Descriptive Statistics for Salary by Academic Rank:")
print(df)

# Visualize the data: Plot median salary by academic rank
plt.figure(figsize=(10, 6))  # Adjust the figure size
plt.bar(df['Academic Rank'], df['Median'], color='skyblue')
plt.xlabel('Academic Rank')
plt.ylabel('Median Salary')
plt.title('Median Salary by Academic Rank')
plt.grid(True)  # Add grid lines
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.tight_layout()  # Adjust layout to prevent clipping of labels
plt.show()
# Out:
# Descriptive Statistics for Salary by Academic Rank:
#   Academic Rank    Median        Mean  Std. Deviation  \
# 0     AssocProf  103613.0   91786.231       18571.184
# 1      AsstProf   78500.0   81362.789        9381.245
# 2          Prof  123321.5  123624.804       24850.288
#
#    Coefficient of Variation  Skewness  Kurtosis  Minimum   Maximum  \
# 0                     0.202    -0.151    -1.614  62884.0  119800.0
# 1                     0.115     0.031    -1.011  63100.0   97032.0
# 2                     0.201     0.070     0.201  57800.0  186960.0
#
#    25th percentile  50th percentile  75th percentile  10th percentile  \
# 0          74830.0         103613.0        104542.00          71512.0
# 1          74096.0          78500.0         91150.00          72500.0
# 2         105112.5         123321.5        143512.25          93675.0
#
#    20th percentile  30th percentile  40th percentile  60th percentile  \
# ...
